# %% [markdown]
# <a href="https://colab.research.google.com/github/BHUVANESWARI-2005/Titanic-Survival-Prediction/blob/main/Titanic_survival_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot, plot
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/tested.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
def missing_values_percent(dataframe):
    missing_values = dataframe.isna().sum()
    percentage_missing = (missing_values / len(dataframe) * 100).round(2)

    result_movie = pd.DataFrame({'Missing Values': missing_values, 'Percentage': percentage_missing})
    result_movie['Percentage'] = result_movie['Percentage'].astype(str) + '%'

    return result_movie


result = missing_values_percent(df)
result
# Out:
#              Missing Values Percentage
# PassengerId               0       0.0%
# Survived                  0       0.0%
# Pclass                    0       0.0%
# Name                      0       0.0%
# Sex                       0       0.0%
# Age                      86     20.57%
# SibSp                     0       0.0%
# Parch                     0       0.0%
# Ticket                    0       0.0%
# Fare                      1      0.24%
# Cabin                   327     78.23%
# Embarked                  0       0.0%

# %%
df = df.dropna()
gender_mapping = {'male': 0, 'female': 1}
df['Sex'] = df['Sex'].map(gender_mapping)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name  Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)    1  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...    1  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    1  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild    1  22.0      0
# 28                            Brady, Mr. John Bertram    0  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 26      1       113509   61.9792              B36        C
# 28      0       113054   30.5000              A21        S

# %%
df['Age'] = df['Age'].round().astype(int)
df['Fare'] = df['Fare'].round().astype(int)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name  Sex  Age  SibSp  Parch  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)    1   23      1      0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...    1   47      1      0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    1   48      1      3
# 26                       Ostby, Miss. Helene Ragnhild    1   22      0      1
# 28                            Brady, Mr. John Bertram    0   41      0      0
#
#          Ticket  Fare            Cabin Embarked
# 12        21228    82              B45        S
# 14  W.E.P. 5734    61              E31        S
# 24     PC 17608   262  B57 B59 B63 B66        C
# 26       113509    62              B36        C
# 28       113054    30              A21        S

# %%
df.drop(['PassengerId','Name','Ticket','Cabin', 'Embarked'],axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 12 to 414
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  87 non-null     int64
#  1   Pclass    87 non-null     int64
#  2   Sex       87 non-null     int64
#  3   Age       87 non-null     int64
#  4   SibSp     87 non-null     int64
#  5   Parch     87 non-null     int64
#  6   Fare      87 non-null     int64
# dtypes: int64(7)
# memory usage: 5.4 KB

# %%
X = df.drop('Survived', axis=1)
y = df['Survived']
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (69, 6)
# (69, 1)
# (18, 6)
# (18, 1)

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=6))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                70
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
past = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 415ms/step - loss: 0.5592 - mean_absolute_error: 0.5825 - val_loss: 0.4885 - val_mean_absolute_error: 0.5066
# Epoch 2/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5215 - mean_absolute_error: 0.5548 - val_loss: 0.4548 - val_mean_absolute_error: 0.4858
# Epoch 3/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4828 - mean_absolute_error: 0.5288 - val_loss: 0.4230 - val_mean_absolute_error: 0.4727
# Epoch 4/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.4487 - mean_absolute_error: 0.5108 - val_loss: 0.3929 - val_mean_absolute_error: 0.4620
# Epoch 5/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4166 - mean_absolute_error: 0.4975 - val_loss: 0.3647 - val_mean_absolute_error: 0.4518
# Epoch 6/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3868 - mean_absolute_error: 0.4861 - val_loss: 0.3384 - val_mean_absolute_error: 0.4441
# Epoch 7/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3572 - mean_absolute_error: 0.4745 - val_loss: 0.3139 - val_mean_absolute_error: 0.4364
# Epoch 8/50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.3301 - mean_absolute_error: 0.4642 - val_loss: 0.2911 - val_mean_absolute_error: 0.4285
# Epoch 9/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3042 - mean_absolute_error: 0.4530 - val_loss: 0.2700 - val_mean_absolute_error: 0.4207
# Epoch 10/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2830 - mean_absolute_error: 0.4447 - val_loss: 0.2504 - val_mean_absolute_error: 0.4130
# Epoch 11/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2627 - mean_absolute_error: 0.4357 - val_loss: 0.2323 - val_mean_absolute_error: 0.4052
# Epoch 12/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2420 - mean_absolute_error: 0.4248 - val_loss: 0.2158 - val_mean_absolute_error: 0.3974
# Epoch 13/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2245 - mean_absolute_error: 0.4156 - val_loss: 0.2003 - val_mean_absolute_error: 0.3896
# Epoch 14/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2062 - mean_absolute_error: 0.4041 - val_loss: 0.1862 - val_mean_absolute_error: 0.3819
# Epoch 15/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1914 - mean_absolute_error: 0.3955 - val_loss: 0.1733 - val_mean_absolute_error: 0.3745
# Epoch 16/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1763 - mean_absolute_error: 0.3847 - val_loss: 0.1617 - val_mean_absolute_error: 0.3673
# Epoch 17/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1644 - mean_absolute_error: 0.3757 - val_loss: 0.1511 - val_mean_absolute_error: 0.3601
# Epoch 18/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1532 - mean_absolute_error: 0.3663 - val_loss: 0.1415 - val_mean_absolute_error: 0.3530
# Epoch 19/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1428 - mean_absolute_error: 0.3578 - val_loss: 0.1329 - val_mean_absolute_error: 0.3460
# Epoch 20/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1337 - mean_absolute_error: 0.3484 - val_loss: 0.1253 - val_mean_absolute_error: 0.3392
# Epoch 21/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1258 - mean_absolute_error: 0.3397 - val_loss: 0.1186 - val_mean_absolute_error: 0.3325
# Epoch 22/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1187 - mean_absolute_error: 0.3313 - val_loss: 0.1125 - val_mean_absolute_error: 0.3259
# Epoch 23/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1127 - mean_absolute_error: 0.3234 - val_loss: 0.1072 - val_mean_absolute_error: 0.3194
# Epoch 24/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1068 - mean_absolute_error: 0.3149 - val_loss: 0.1025 - val_mean_absolute_error: 0.3132
# Epoch 25/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1021 - mean_absolute_error: 0.3075 - val_loss: 0.0984 - val_mean_absolute_error: 0.3073
# Epoch 26/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0981 - mean_absolute_error: 0.3001 - val_loss: 0.0947 - val_mean_absolute_error: 0.3014
# Epoch 27/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0942 - mean_absolute_error: 0.2926 - val_loss: 0.0913 - val_mean_absolute_error: 0.2957
# Epoch 28/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0904 - mean_absolute_error: 0.2854 - val_loss: 0.0881 - val_mean_absolute_error: 0.2901
# Epoch 29/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0877 - mean_absolute_error: 0.2794 - val_loss: 0.0852 - val_mean_absolute_error: 0.2845
# Epoch 30/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0842 - mean_absolute_error: 0.2730 - val_loss: 0.0824 - val_mean_absolute_error: 0.2792
# Epoch 31/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0817 - mean_absolute_error: 0.2685 - val_loss: 0.0798 - val_mean_absolute_error: 0.2739
# Epoch 32/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0789 - mean_absolute_error: 0.2628 - val_loss: 0.0772 - val_mean_absolute_error: 0.2687
# Epoch 33/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0763 - mean_absolute_error: 0.2578 - val_loss: 0.0748 - val_mean_absolute_error: 0.2637
# Epoch 34/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0738 - mean_absolute_error: 0.2529 - val_loss: 0.0723 - val_mean_absolute_error: 0.2587
# Epoch 35/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0713 - mean_absolute_error: 0.2480 - val_loss: 0.0699 - val_mean_absolute_error: 0.2537
# Epoch 36/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0686 - mean_absolute_error: 0.2428 - val_loss: 0.0675 - val_mean_absolute_error: 0.2487
# Epoch 37/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0661 - mean_absolute_error: 0.2376 - val_loss: 0.0651 - val_mean_absolute_error: 0.2436
# Epoch 38/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0634 - mean_absolute_error: 0.2324 - val_loss: 0.0625 - val_mean_absolute_error: 0.2384
# Epoch 39/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0608 - mean_absolute_error: 0.2271 - val_loss: 0.0600 - val_mean_absolute_error: 0.2331
# Epoch 40/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0582 - mean_absolute_error: 0.2217 - val_loss: 0.0575 - val_mean_absolute_error: 0.2280
# Epoch 41/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0555 - mean_absolute_error: 0.2161 - val_loss: 0.0551 - val_mean_absolute_error: 0.2229
# Epoch 42/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0529 - mean_absolute_error: 0.2107 - val_loss: 0.0527 - val_mean_absolute_error: 0.2178
# Epoch 43/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0502 - mean_absolute_error: 0.2053 - val_loss: 0.0504 - val_mean_absolute_error: 0.2128
# Epoch 44/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0479 - mean_absolute_error: 0.2002 - val_loss: 0.0480 - val_mean_absolute_error: 0.2076
# Epoch 45/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0453 - mean_absolute_error: 0.1945 - val_loss: 0.0458 - val_mean_absolute_error: 0.2025
# Epoch 46/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0429 - mean_absolute_error: 0.1890 - val_loss: 0.0436 - val_mean_absolute_error: 0.1973
# Epoch 47/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0406 - mean_absolute_error: 0.1836 - val_loss: 0.0414 - val_mean_absolute_error: 0.1920
# Epoch 48/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0381 - mean_absolute_error: 0.1777 - val_loss: 0.0390 - val_mean_absolute_error: 0.1861
# Epoch 49/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0360 - mean_absolute_error: 0.1723 - val_loss: 0.0366 - val_mean_absolute_error: 0.1801
# Epoch 50/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0335 - mean_absolute_error: 0.1661 - val_loss: 0.0343 - val_mean_absolute_error: 0.1740

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 150ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.7933533989782436
